# %%
# THIS FILE DOESN'T DIFFER SIGNIFICANTLY FROM THE RANDOM SAMPLING ONE YET

# %%
import os, sys
import pandas as pd
import matplotlib.pyplot as plt
import time

from IPython.display import Image
import torch
from collections import defaultdict
import imageio
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import random

import math

from get_tensor import get_samples, get_batch, display_image

# %%
csv_src = "..\..\..\coords-scattered-hdr.csv"
skies_data = pd.read_csv(csv_src)
skies_data.insert(0, "TensorIndex", [num for num in range(len(skies_data))], False)
skies_data
# Out:
#        TensorIndex       Date      Time  SunAzimuth  SunAltitude  \
# 0                0  11/6/2012  12:32:26    191.9511      30.5111
# 1                1  11/6/2012  12:32:26    191.9511      30.5111
# 2                2  11/6/2012  12:32:26    191.9511      30.5111
# 3                3  11/6/2012  12:32:26    191.9511      30.5111
# 4                4  11/6/2012  12:32:26    191.9511      30.5111
# ...            ...        ...       ...         ...          ...
# 16370        16370  9/26/2013  15:40:01    244.1781      23.4249
# 16371        16371  9/26/2013  15:40:01    244.1781      23.4249
# 16372        16372  9/26/2013  15:40:01    244.1781      23.4249
# 16373        16373  9/26/2013  15:40:01    244.1781      23.4249
# 16374        16374  9/26/2013  15:40:01    244.1781      23.4249
#
#        SamplePatternIndex  SampleAzimuth  SampleAltitude  SunPointAngle  \
# 0                       0           0.00         12.1151        135.851
# 1                       1         348.75         12.1151        131.887
# 2                       2         337.50         12.1151        126.019
# 3                       3         326.25         12.1151        118.799
# 4                       4         315.00         12.1151        110.660
# ...                   ...            ...             ...            ...
# 16370                  76         225.00         71.9187         49.692
# 16371                  77         270.00         71.9187         50.634
# 16372                  78         315.00         71.9187         61.870
# 16373                  79           0.00         71.9187         75.293
# 16374                  80           0.00         90.0000         66.575
#
#        ColorA5  ...      1773      1774      1775      1776      1777  \
# 0            0  ...  0.003172  0.002996  0.002875  0.002726  0.002590
# 1            0  ...  0.000429  0.000456  0.000420  0.000399  0.000385
# 2            0  ...  0.000198  0.000197  0.000231  0.000260  0.000254
# 3            0  ...  0.000445  0.000406  0.000392  0.000370  0.000339
# 4            0  ...  0.000745  0.000717  0.000689  0.000618  0.000597
# ...        ...  ...       ...       ...       ...       ...       ...
# 16370        0  ...  0.000186  0.000163  0.000130  0.000120  0.000112
# 16371        0  ...  0.002164  0.002111  0.002037  0.001972  0.001907
# 16372        0  ...  0.010306  0.010025  0.009749  0.009450  0.009159
# 16373        0  ...  0.004649  0.004518  0.004371  0.004213  0.004082
# 16374        0  ...  0.001224  0.001199  0.001186  0.001146  0.001121
#
#            1778      1779      1780         u         v
# 0      0.002480  0.002348  0.002258  0.500000  0.951278
# 1      0.000342  0.000355  0.000359  0.411960  0.942607
# 2      0.000194  0.000153  0.000107  0.327303  0.916927
# 3      0.000293  0.000316  0.000333  0.249283  0.875224
# 4      0.000655  0.000644  0.000641  0.180898  0.819102
# ...         ...       ...       ...       ...       ...
# 16370  0.000106  0.000118  0.000123  0.419001  0.419001
# 16371  0.001828  0.001788  0.001735  0.385450  0.500000
# 16372  0.008849  0.008572  0.008330  0.419001  0.580999
# 16373  0.003955  0.003848  0.003759  0.500000  0.614550
# 16374  0.001081  0.001041  0.001019  0.500000  0.500000
#
# [16375 rows x 1454 columns]

# %%
display_image(get_samples(skies_data.iloc[0]).cpu()[18:21])

# %%
spectrum_beginning = 350
spectrum_end = 1780
n_frequencies = 1780 - 350 + 1

y = skies_data[
    [
        str(number)
        for number in range(spectrum_beginning, spectrum_end + 1)
    ]
]

y_mean = y.mean(0)
y_range = y.max(0) - y.min(0)

normalized_y = (y - y_mean) / y_range # maybe use range instead of std
normalized_y_tensor = torch.tensor(normalized_y.values).float()
print(normalized_y_tensor.shape)
normalized_y
# Out:
# torch.Size([16375, 1431])
#             350       351       352       353       354       355       356  \
# 0     -0.046257 -0.045275 -0.044457 -0.043714 -0.042926 -0.041975 -0.041086
# 1     -0.000729 -0.000044  0.000486  0.000965  0.001510  0.002271  0.002814
# 2     -0.004281 -0.003518 -0.002893 -0.002391 -0.001916 -0.001283 -0.000731
# 3     -0.009639 -0.008976 -0.008458 -0.007975 -0.007452 -0.006855 -0.006421
# 4     -0.018628 -0.017955 -0.017530 -0.017116 -0.016593 -0.015984 -0.015444
# ...         ...       ...       ...       ...       ...       ...       ...
# 16370 -0.083436 -0.083143 -0.082619 -0.082629 -0.083014 -0.082630 -0.081998
# 16371 -0.075954 -0.075869 -0.075286 -0.075062 -0.075155 -0.074580 -0.073886
# 16372 -0.039008 -0.038192 -0.036883 -0.036041 -0.035627 -0.034531 -0.032997
# 16373 -0.079029 -0.078546 -0.077582 -0.077094 -0.077051 -0.076409 -0.075323
# 16374 -0.095895 -0.095783 -0.095347 -0.095259 -0.095398 -0.094819 -0.094128
#
#             357       358       359  ...      1771      1772      1773  \
# 0     -0.040325 -0.039643 -0.038697  ... -0.000993 -0.001103 -0.001324
# 1      0.003156  0.003481  0.003924  ... -0.017640 -0.017726 -0.017623
# 2     -0.000342 -0.000113  0.000155  ... -0.019097 -0.018997 -0.018994
# 3     -0.006047 -0.005552 -0.005125  ... -0.017454 -0.017398 -0.017523
# 4     -0.015076 -0.014889 -0.014445  ... -0.015950 -0.015907 -0.015743
# ...         ...       ...       ...  ...       ...       ...       ...
# 16370 -0.081547 -0.081543 -0.081248  ... -0.019175 -0.019140 -0.019064
# 16371 -0.073403 -0.073264 -0.072784  ... -0.007244 -0.007350 -0.007309
# 16372 -0.031681 -0.031148 -0.029915  ...  0.041191  0.041205  0.041066
# 16373 -0.074391 -0.074160 -0.073464  ...  0.007594  0.007455  0.007454
# 16374 -0.093579 -0.093217 -0.092566  ... -0.013051 -0.012932 -0.012900
#
#            1774      1775      1776      1777      1778      1779      1780
# 0     -0.001902 -0.002143 -0.002568 -0.002949 -0.003165 -0.003606 -0.003807
# 1     -0.017385 -0.017518 -0.017559 -0.017561 -0.017748 -0.017574 -0.017480
# 2     -0.018958 -0.018703 -0.018453 -0.018424 -0.018764 -0.018994 -0.019295
# 3     -0.017689 -0.017691 -0.017745 -0.017865 -0.018086 -0.017852 -0.017667
# 4     -0.015793 -0.015836 -0.016150 -0.016154 -0.015618 -0.015549 -0.015447
# ...         ...       ...       ...       ...       ...       ...       ...
# 16370 -0.019165 -0.019334 -0.019358 -0.019367 -0.019364 -0.019240 -0.019176
# 16371 -0.007294 -0.007389 -0.007421 -0.007473 -0.007616 -0.007527 -0.007568
# 16372  0.040948  0.040915  0.040758  0.040571  0.040274  0.040038  0.039917
# 16373  0.007380  0.007230  0.007014  0.006939  0.006890  0.006914  0.007000
# 16374 -0.012850 -0.012720 -0.012743 -0.012680 -0.012712 -0.012770 -0.012730
#
# [16375 rows x 1431 columns]

# %%
# normalization
# we divide the brightness by 255 in the get_samples code
load_samples = True
save_location = '..\..\..\sky_samples_not_random'
if load_samples:
    sky_sample_tensors = torch.load('..\..\..\sky_samples_not_random')
else:
    sky_sample_tensors = get_batch(skies_data, 0, len(skies_data), get_samples)
    torch.save(sky_sample_tensors, save_location)

sky_sample_tensors.shape, sys.getsizeof(sky_sample_tensors.storage())
# Out:
# (torch.Size([16375, 24, 100, 100]), 15720000056)

# %%
# These skies are the ones we will use to validate our model against the original model
demo_skies = [ # first 4 clear, next 4 scattered, last 3 overcast
    ("5/26/2013", "15:15"), # (date, time)
    ("5/27/2013", "10:15"),
    ("7/26/2013", "13:15"),
    ("9/24/2013", "15:39"),
    ("5/12/2013", "13:00"),
    ("5/26/2013", "12:30"),
    ("7/29/2013", "10:00"),
    ("9/26/2013", "11:50"),
    ("4/14/2013", "11:36"),
    ("4/15/2013", "08:40"),
    ("7/29/2013", "13:30")
]
date_to_time = {sky[0]: sky[1] for sky in demo_skies}

drop_indexes = []

for index, series in skies_data.iterrows():
    if series["Date"] in date_to_time:
        if series["Time"][:5] == date_to_time[series["Date"]]:
            print(index, list(series[["Date", "Time", "SamplePatternIndex"]]))
            drop_indexes.append(index)
pruned_skies_data = skies_data.drop(index=drop_indexes).reset_index(drop=True)

prev_date_time = tuple(pruned_skies_data.iloc[0][["Date", "Time"]])
sky_start_index = 0
skies_indexes = [] # (start_index, length)
for index, series in pruned_skies_data.iterrows():
    current_date_time = tuple(series[["Date", "Time"]])
    if prev_date_time != current_date_time:
        prev_date_time = current_date_time
        skies_indexes.append((sky_start_index, index - sky_start_index))
        sky_start_index = index
skies_indexes.append((sky_start_index, pruned_skies_data.shape[0] - sky_start_index))

sky_number_column = []
for number, index_and_length in enumerate(skies_indexes):
    sky_number_column += [number for _ in range(index_and_length[1])]

pruned_skies_data.insert(0, "SkyNumber", sky_number_column, False)

random.seed(0)
random.shuffle(skies_indexes)

indexes = []
for index, length in skies_indexes:
    indexes += [index + i for i in range(length)]

shuffled_skies = pruned_skies_data.iloc[indexes].reset_index(drop=True)
    
training_ratio = 0.75
sky_index = 0
prev_sky_number = int(shuffled_skies.iloc[0]["SkyNumber"])
n_skies = len(skies_indexes)
separator_index = 0
for index, series in shuffled_skies.iterrows():
    current_sky_number = int(series["SkyNumber"])
    if current_sky_number != prev_sky_number:
        prev_sky_number = current_sky_number
        sky_index += 1
        if (sky_index / n_skies) >= 0.75:
            separator_index = index
            break

train_skies_data = pruned_skies_data.iloc[:separator_index].sample(frac=1.0, random_state=0)
test_skies_data = pruned_skies_data.iloc[separator_index:].sample(frac=1.0, random_state=0)
# Out:
# 6508 ['5/12/2013', '13:00:01', 0]
# 6509 ['5/12/2013', '13:00:01', 1]
# 6510 ['5/12/2013', '13:00:01', 2]
# 6511 ['5/12/2013', '13:00:01', 3]
# 6512 ['5/12/2013', '13:00:01', 4]
# 6513 ['5/12/2013', '13:00:01', 5]
# 6514 ['5/12/2013', '13:00:01', 6]
# 6515 ['5/12/2013', '13:00:01', 7]
# 6516 ['5/12/2013', '13:00:01', 8]
# 6517 ['5/12/2013', '13:00:01', 9]
# 6518 ['5/12/2013', '13:00:01', 10]
# 6519 ['5/12/2013', '13:00:01', 11]
# 6520 ['5/12/2013', '13:00:01', 12]
# 6521 ['5/12/2013', '13:00:01', 13]
# 6522 ['5/12/2013', '13:00:01', 14]
# 6523 ['5/12/2013', '13:00:01', 15]
# 6524 ['5/12/2013', '13:00:01', 16]
# 6525 ['5/12/2013', '13:00:01', 17]
# 6526 ['5/12/2013', '13:00:01', 18]
# 6527 ['5/12/2013', '13:00:01', 19]
# 6528 ['5/12/2013', '13:00:01', 20]
# 6529 ['5/12/2013', '13:00:01', 21]
# 6530 ['5/12/2013', '13:00:01', 22]
# 6531 ['5/12/2013', '13:00:01', 23]
# 6532 ['5/12/2013', '13:00:01', 24]
# 6533 ['5/12/2013', '13:00:01', 25]
# 6534 ['5/12/2013', '13:00:01', 26]
# 6535 ['5/12/2013', '13:00:01', 27]
# 6536 ['5/12/2013', '13:00:01', 28]
# 6537 ['5/12/2013', '13:00:01', 29]
# 6538 ['5/12/2013', '13:00:01', 30]
# 6539 ['5/12/2013', '13:00:01', 31]
# 6540 ['5/12/2013', '13:00:01', 32]
# 6541 ['5/12/2013', '13:00:01', 33]
# 6542 ['5/12/2013', '13:00:01', 34]
# 6543 ['5/12/2013', '13:00:01', 35]
# 6544 ['5/12/2013', '13:00:01', 36]
# 6545 ['5/12/2013', '13:00:01', 37]
# 6546 ['5/12/2013', '13:00:01', 38]
# 6547 ['5/12/2013', '13:00:01', 39]
# 6548 ['5/12/2013', '13:00:01', 40]
# 6549 ['5/12/2013', '13:00:01', 41]
# 6550 ['5/12/2013', '13:00:01', 42]
# 6551 ['5/12/2013', '13:00:01', 43]
# 6552 ['5/12/2013', '13:00:01', 44]
# 6553 ['5/12/2013', '13:00:01', 45]
# 6554 ['5/12/2013', '13:00:01', 46]
# 14552 ['9/26/2013', '11:50:01', 4]
# 14553 ['9/26/2013', '11:50:01', 5]
# 14554 ['9/26/2013', '11:50:01', 6]
# 14555 ['9/26/2013', '11:50:01', 7]
# 14556 ['9/26/2013', '11:50:01', 8]
# 14557 ['9/26/2013', '11:50:01', 9]
# 14558 ['9/26/2013', '11:50:01', 10]
# 14559 ['9/26/2013', '11:50:01', 11]
# 14560 ['9/26/2013', '11:50:01', 12]
# 14561 ['9/26/2013', '11:50:01', 13]
# 14562 ['9/26/2013', '11:50:01', 14]
# 14563 ['9/26/2013', '11:50:01', 15]
# 14564 ['9/26/2013', '11:50:01', 16]
# 14565 ['9/26/2013', '11:50:01', 17]
# 14566 ['9/26/2013', '11:50:01', 18]
# 14567 ['9/26/2013', '11:50:01', 19]
# 14568 ['9/26/2013', '11:50:01', 20]
# 14569 ['9/26/2013', '11:50:01', 21]
# 14570 ['9/26/2013', '11:50:01', 22]
# 14571 ['9/26/2013', '11:50:01', 23]
# 14572 ['9/26/2013', '11:50:01', 24]
# 14573 ['9/26/2013', '11:50:01', 25]
# 14574 ['9/26/2013', '11:50:01', 26]
# 14575 ['9/26/2013', '11:50:01', 27]
# 14576 ['9/26/2013', '11:50:01', 28]
# 14577 ['9/26/2013', '11:50:01', 29]
# 14578 ['9/26/2013', '11:50:01', 30]
# 14579 ['9/26/2013', '11:50:01', 31]
# 14580 ['9/26/2013', '11:50:01', 32]
# 14581 ['9/26/2013', '11:50:01', 33]
# 14582 ['9/26/2013', '11:50:01', 34]
# 14583 ['9/26/2013', '11:50:01', 35]
# 14584 ['9/26/2013', '11:50:01', 36]
# 14585 ['9/26/2013', '11:50:01', 37]
# 14586 ['9/26/2013', '11:50:01', 38]
# 14587 ['9/26/2013', '11:50:01', 39]
# 14588 ['9/26/2013', '11:50:01', 40]
# 14589 ['9/26/2013', '11:50:01', 41]
# 14590 ['9/26/2013', '11:50:01', 43]
# 14591 ['9/26/2013', '11:50:01', 44]
# 14592 ['9/26/2013', '11:50:01', 45]
# 14593 ['9/26/2013', '11:50:01', 46]
# 14594 ['9/26/2013', '11:50:01', 47]
# 14595 ['9/26/2013', '11:50:01', 48]
# 14596 ['9/26/2013', '11:50:01', 49]
# 14597 ['9/26/2013', '11:50:01', 50]
# 14598 ['9/26/2013', '11:50:01', 51]
# 14599 ['9/26/2013', '11:50:01', 52]
# 14600 ['9/26/2013', '11:50:01', 53]
# 14601 ['9/26/2013', '11:50:01', 54]
# 14602 ['9/26/2013', '11:50:01', 55]
# 14603 ['9/26/2013', '11:50:01', 56]
# 14604 ['9/26/2013', '11:50:01', 57]
# 14605 ['9/26/2013', '11:50:01', 58]
# 14606 ['9/26/2013', '11:50:01', 59]
# 14607 ['9/26/2013', '11:50:01', 60]
# 14608 ['9/26/2013', '11:50:01', 61]
# 14609 ['9/26/2013', '11:50:01', 62]
# 14610 ['9/26/2013', '11:50:01', 63]
# 14611 ['9/26/2013', '11:50:01', 64]
# 14612 ['9/26/2013', '11:50:01', 65]
# 14613 ['9/26/2013', '11:50:01', 66]
# 14614 ['9/26/2013', '11:50:01', 67]
# 14615 ['9/26/2013', '11:50:01', 68]
# 14616 ['9/26/2013', '11:50:01', 69]
# 14617 ['9/26/2013', '11:50:01', 70]
# 14618 ['9/26/2013', '11:50:01', 71]
# 14619 ['9/26/2013', '11:50:01', 72]
# 14620 ['9/26/2013', '11:50:01', 73]
# 14621 ['9/26/2013', '11:50:01', 74]
# 14622 ['9/26/2013', '11:50:01', 75]
# 14623 ['9/26/2013', '11:50:01', 76]
# 14624 ['9/26/2013', '11:50:01', 77]
# 14625 ['9/26/2013', '11:50:01', 78]
# 14626 ['9/26/2013', '11:50:01', 79]
# 14627 ['9/26/2013', '11:50:01', 80]

# %%
model = nn.Sequential(
    nn.Conv2d(3 * 8, 64, 7, padding=(3, 3)), # 100x100
    nn.MaxPool2d(2, 2), # 50x50
    nn.ReLU(inplace=True),

    nn.Conv2d(64, 128, 5, padding=(2, 2)), # 50x50
    nn.MaxPool2d(2, 2), # 25, 25
    nn.ReLU(inplace=True),
    
    nn.Conv2d(128, 256, 3, padding=(1, 1)), # 25x25
    nn.AdaptiveMaxPool2d(16), # 16x16
    nn.ReLU(inplace=True),
    
    nn.Conv2d(256, 512, 2, stride=(2, 2), padding=(0, 0)), # 8x8
    nn.ReLU(inplace=True),

    nn.Conv2d(512, 1024, 2, stride=(2, 2), padding=(0, 0)), # 4x4
    nn.ReLU(inplace=True),
    
    nn.Flatten(),

    nn.Dropout(),
    nn.Linear(1024 * 4 * 4, 8192),
    nn.ReLU(inplace=True),
    
    nn.Dropout(p=0.7),
    nn.Linear(8192, 4096),
    nn.ReLU(inplace=True),
    
    nn.Linear(4096, n_frequencies)
)

train_model = False
epochs = 500
batch_size = 100

# %%
state_dict_save = None
if train_model:
    start_time = time.time()

    model.cuda()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.000001)
    criterion = torch.nn.MSELoss(reduction='sum')
    first_epochs_training_loss = 0
    first_epochs_testing_loss = 0
    
    prev_testing_loss = 0
    
    for epoch in range(epochs):
        total_training_loss = 0
        total_testing_loss = 0

        train_n_batches = math.ceil(train_skies_data.shape[0] / batch_size)
        model.train()
        for i in range(train_n_batches):
            start = i * batch_size
            samples_indexes = list(train_skies_data[start: start + batch_size]["TensorIndex"])

            batch = sky_sample_tensors[samples_indexes].cuda()
            ground_truth = normalized_y_tensor[samples_indexes].cuda()

            pred = model(batch)
            loss = criterion(pred, ground_truth)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_training_loss += float(loss)


        test_n_batches = math.ceil(test_skies_data.shape[0] / batch_size)
        model.eval()
        for i in range(test_n_batches):
            start = i * batch_size
            samples_indexes = list(test_skies_data[start: start + batch_size]["TensorIndex"])

            batch = sky_sample_tensors[samples_indexes].cuda()
            ground_truth = normalized_y_tensor[samples_indexes].cuda()

            pred = model(batch)
            loss = criterion(pred, ground_truth)

            total_testing_loss += float(loss)
            

        tab_char = '\t'
        print(f"{epoch}\tTraining Loss: {total_training_loss:.2f}\t{tab_char if total_training_loss < 100000 else ''}Testing Loss: {total_testing_loss:.2f}")
        if epoch == 0:
            first_epochs_training_loss = total_training_loss
            first_epochs_testing_loss = total_testing_loss
            prev_testing_loss = total_testing_loss
            state_dict_save = model.state_dict()

        change_in_training = total_training_loss - first_epochs_training_loss # I could use a func to calculate change
        change_in_training = change_in_training * 100 / first_epochs_training_loss
        change_in_training = " " * 15 + f'{"+" if change_in_training >= 0 else ""}{change_in_training:.2f}'

        change_in_testing = total_testing_loss - first_epochs_testing_loss
        change_in_testing = change_in_testing * 100 / first_epochs_testing_loss
        change_in_testing = " " * 22 + f'{"+" if change_in_testing >= 0 else ""}{change_in_testing:.2f}'

        print(f"\t{change_in_training}%\t{change_in_testing}%")

        minutes_elapsed_since_start = round((time.time() - start_time) / 60)
        print(f"Minutes Training: {minutes_elapsed_since_start}\n")
        
        if total_testing_loss < prev_testing_loss:
            state_dict_save = model.state_dict()
            
        prev_testing_loss = total_testing_loss

    model.load_state_dict(state_dict_save)
    model.cpu()
    torch.save(state_dict_save, '..\..\..\sky_model_sky_sampling')

else:
    model.load_state_dict(torch.load('..\..\..\sky_model_sky_sampling'))
    model.eval()

# %%
test_tensor_indexes = list(test_skies_data["TensorIndex"])

truth = normalized_y_tensor[test_tensor_indexes]
truth_visible_range = truth[:,(380-350):(780-350)]
truth_infrared = truth[:,(780-350):]
truth.shape
# Out:
# torch.Size([4000, 1431])

# %%
pred = model(sky_sample_tensors[test_tensor_indexes]).detach()
pred_visible_range = pred[:,(380-350):(780-350)]
pred_infrared = pred[:,(780-350):]
pred.shape
# Out:
# torch.Size([4000, 1431])

# %%
range_all = y_range
range_visible = y_range[(380-350):(780-350)]
range_infrared = y_range[(780-350):]

def rmsd(pred_t, truth_t, range_t):
    diff_squared = ((pred_t - truth_t) * torch.tensor(range_t).float()) ** 2
    return diff_squared.sum(dim=1).mean().sqrt() * 100
    
rmsd_all = rmsd(pred, truth, range_all)
rmsd_visible = rmsd(pred_visible_range, truth_visible_range, range_visible)
rmsd_infrared = rmsd(pred_infrared, truth_infrared, range_infrared)
rmsd_all, rmsd_visible, rmsd_infrared
# Out:
# (tensor(94.3000), tensor(80.4855), tensor(48.0040))

# %%
n = 4
display_image(sky_sample_tensors[n][18:21])
wavelengths = [number for number in range(350, 1780 + 1)]

print(rmsd(pred[n:n+1], truth[n:n+1], range_all))

fig, (ax1) = plt.subplots(1)
ax1.plot(wavelengths, pred[n] * range_all + y_mean, color="silver", label=f"Pred")
ax1.plot(wavelengths, truth[n] * range_all + y_mean, "gold", label="Ground Truth")
ax1.legend()
plt.xlabel("Wavelength (nm)")
# Out:
# tensor(30.8477)
# Text(0.5, 0, 'Wavelength (nm)')

# %%
def compare_and_plot():
    pass
